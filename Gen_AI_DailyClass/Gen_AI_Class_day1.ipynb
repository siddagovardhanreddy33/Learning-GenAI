# %%
print('Hello world')
# Out:
# Hello world

# %%
# !pip install google-genai
# Out:
# ...
#    ---------------------------------------- 0.0/790.4 kB ? eta -:--:--
#    ---------------------------------------- 790.4/790.4 kB 8.5 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------- ----------------- 2.1/3.8 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 9.3 MB/s  0:00:00
# ...
#
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    --- ------------------------------------  1/13 [tenacity]
#    --- ------------------------------------  1/13 [tenacity]
# ...

# %%
# !pip show google-genai
# Out:
# Name: google-genai
# Version: 1.74.0
# Summary: GenAI Python SDK
# Home-page: https://github.com/googleapis/python-genai
# Author:
# Author-email: Google LLC <googleapis-packages@google.com>
# License-Expression: Apache-2.0
# Location: c:\users\sidda\appdata\local\programs\python\python310\lib\site-packages
# Requires: anyio, distro, google-auth, httpx, pydantic, requests, sniffio, tenacity, typing-extensions, websockets
# Required-by:

# %%
from google import genai

# %%
## clint - through api key , can access Genai LLM - available in google server

# %%
# client = genai.Client(api_key='YOUR_API_KEY')  not recomanded practice

# %%
clint = genai.client() 
clint
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 clint = genai.client()
#       2 clint
#
# TypeError: 'module' object is not callable

# %% [markdown]
# ### Recommended

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os

# %%
os.getenv('gemini')
# Out:
# 'AIzaSyCUFQpf8xmh3QhrF-7HMAMxOuHEyN9xEEg'

# %%
os.environ['GEMINI_API_KEY']=os.getenv('gemini')

# %%
from google import genai

# %%
client = genai.Client()
client

# %%
# Generate response using Gemini model

response = client.models.generate_content(
    model='gemini-2.5-flash-lite',  # Model name
    contents='what are the advantages of gemini llms over other providers'  # Prompt
)

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""Gemini LLMs offer a compelling set of advantages over other providers, primarily stemming from their **multimodal capabilities, advanced reasoning, and scalability**. Here's a breakdown of the key benefits:
#
# **1. True Multimodality:**
#
# *   **Integrated Understanding:** Unlike models that might process text and images separately, Gemini is designed from the ground up to understand and operate across various modalities (text, images, audio, video, code) simultaneously. This means it can:
#     *   **Analyze and reason about complex relationships between different data types.** For example, it can describe what's happening in a video, explain the code generating a visual, or answer questions about an image based on accompanying text.
# ...

# %%
# Print the response
print(response.text)
# Out:
# Gemini LLMs offer a compelling set of advantages over other providers, primarily stemming from their **multimodal capabilities, advanced reasoning, and scalability**. Here's a breakdown of the key benefits:
#
# **1. True Multimodality:**
#
# *   **Integrated Understanding:** Unlike models that might process text and images separately, Gemini is designed from the ground up to understand and operate across various modalities (text, images, audio, video, code) simultaneously. This means it can:
#     *   **Analyze and reason about complex relationships between different data types.** For example, it can describe what's happening in a video, explain the code generating a visual, or answer questions about an image based on accompanying text.
#     *   **Generate richer, more contextually aware outputs.** A description of a recipe could be accompanied by relevant images, or a story could be illustrated.
# ...
