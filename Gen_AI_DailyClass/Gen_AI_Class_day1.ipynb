# %%
print('Hello world')
# Out:
# Hello world

# %%
from google import genai

# %% [markdown]
# ### Not recommended practice

# %%
## clint - through api key , can access Genai LLM - available in google server

# %%
# not recomanded practice
# client = genai.Client(api_key='YOUR_API_KEY')  

# clint = genai.client() 
# clint

# %% [markdown]
# ### Recommended

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os

# %%
os.environ['GEMINI_API_KEY']=os.getenv('gemini')

# %%
from google import genai

# %%
client = genai.Client()
client

# %%
# Generate response using Gemini model

response = client.models.generate_content(
    model='gemini-2.5-flash-lite',  # Model name
    contents='what are the advantages of gemini llms over other providers'  # Prompt
)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[40], line 3
#       1 # Generate response using Gemini model
# ----> 3 response = client.models.generate_content(
#       4     model='gemini-2.5-flash-lite',  # Model name
#       5     contents='what are the advantages of gemini llms over other providers'  # Prompt
#       6 )
#
# File c:\Users\sidda\Desktop\GEN_AI\venv\lib\site-packages\google\genai\models.py:6329, in Models.generate_content(self, model, contents, config)
#    6327 while remaining_remote_calls_afc > 0:
#    6328   i += 1
# -> 6329   response = self._generate_content(
#    6330       model=model, contents=contents, config=parsed_config
#    6331   )
#    6333   function_map = _extra_utils.get_function_map(parsed_config)
#    6334   if not function_map:
#
# File c:\Users\sidda\Desktop\GEN_AI\venv\lib\site-packages\google\genai\models.py:4767, in Models._generate_content(self, model, contents, config)
#    4764 request_dict = _common.convert_to_dict(request_dict)
#    4765 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4767 response = self._api_client.request(
#    4768     'post', path, request_dict, http_options
#    4769 )
#    4771 if config is not None and getattr(
#    4772     config, 'should_return_http_response', None
#    4773 ):
#    4774   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File c:\Users\sidda\Desktop\GEN_AI\venv\lib\site-packages\google\genai\_api_client.py:1579, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1569 def request(
#    1570     self,
#    1571     http_method: str,
#    (...)
#    1574     http_options: Optional[HttpOptionsOrDict] = None,
#    1575 ) -> SdkHttpResponse:
#    1576   http_request = self._build_request(
#    1577       http_method, path, request_dict, http_options
#    1578   )
# -> 1579   response = self._request(http_request, http_options, stream=False)
#    1580   response_body = (
#    1581       response.response_stream[0] if response.response_stream else ''
#    1582   )
#    1583   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File c:\Users\sidda\Desktop\GEN_AI\venv\lib\site-packages\google\genai\_api_client.py:1372, in BaseApiClient._request(self, http_request, http_options, stream)
#    1369     retry = tenacity.Retrying(**retry_kwargs)
#    1370     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1372 return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\sidda\Desktop\GEN_AI\venv\lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File c:\Users\sidda\Desktop\GEN_AI\venv\lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\Users\sidda\Desktop\GEN_AI\venv\lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File c:\Users\sidda\Desktop\GEN_AI\venv\lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File ~\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File c:\Users\sidda\Desktop\GEN_AI\venv\lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\sidda\Desktop\GEN_AI\venv\lib\site-packages\google\genai\_api_client.py:1349, in BaseApiClient._request_once(self, http_request, stream)
#    1341   httpx_request = self._httpx_client.build_request(  # type: ignore[union-attr]
#    1342       method=http_request.method,
#    1343       url=http_request.url,
#    (...)
#    1346       timeout=http_request.timeout,
#    1347   )
#    1348   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1349 errors.APIError.raise_for_response(response)
#    1350 return HttpResponse(
#    1351     response.headers, response if stream else [response.text]
#    1352 )
#
# File c:\Users\sidda\Desktop\GEN_AI\venv\lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     152 else:
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File c:\Users\sidda\Desktop\GEN_AI\venv\lib\site-packages\google\genai\errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     170 """Raises an appropriate APIError subclass based on the status code.
#     171
#     172 Args:
#    (...)
#     181   APIError: For other error status codes.
#     182 """
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#     186   raise ServerError(status_code, response_json, response)
#
# ClientError: 403 PERMISSION_DENIED. {'error': {'code': 403, 'message': 'Your API key was reported as leaked. Please use another API key.', 'status': 'PERMISSION_DENIED'}}

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""Gemini LLMs, as developed by Google AI, offer several potential advantages over LLMs from other providers. It's important to note that the LLM landscape is constantly evolving, and specific advantages can depend on the exact model version and the task at hand. However, here are some of the key strengths and potential advantages often attributed to Gemini:
#
# **1. Multimodality:**
#
# *   **Native Understanding of Multiple Data Types:** This is a flagship feature of Gemini. Unlike many other LLMs that might process different modalities (text, images, audio, video, code) separately or require significant pre-processing to integrate them, Gemini is designed to understand and reason across these modalities **natively and jointly**.
#     *   **Advantage:** This allows for richer interactions, more complex problem-solving, and the ability to draw insights from diverse information sources simultaneously. For example, you could ask Gemini to analyze a chart in an image and then explain its implications in text, or to describe a video and then generate code to recreate a similar effect.
#
# **2. Advanced Reasoning Capabilities:**
#
# *   **Complex Problem Solving:** Gemini has demonstrated strong performance on challenging reasoning benchmarks, including those that require logical deduction, common-sense reasoning, and understanding intricate relationships.
#     *   **Advantage:** This leads to more accurate and insightful responses to complex questions, better decision-making support, and the ability to tackle more sophisticated analytical tasks.
#
# **3. Performance and Efficiency:**
#
# *   **Optimized for Speed and Scalability:** Google has invested heavily in optimizing Gemini for efficient inference and scalability, leveraging their extensive infrastructure.
#     *   **Advantage:** This can translate to faster response times and the ability to handle a larger volume of requests, which is crucial for real-world applications and businesses.
#
# **4. State-of-the-Art Architecture and Training:**
#
# *   **Cutting-Edge Research:** Gemini benefits from Google's deep research in AI, including advancements in neural network architectures, training methodologies, and reinforcement learning.
#     *   **Advantage:** This foundation often results in models that are at the forefront of natural language understanding, generation, and reasoning capabilities.
#
# **5. Potential for Deep Integration with Google Ecosystem:**
#
# *   **Synergy with Google Products:** While not exclusively an advantage of the LLM itself, Gemini's origin within Google suggests potential for seamless integration with other Google services like Search, Workspace, Cloud, and Android.
#     *   **Advantage:** This could lead to more context-aware and helpful experiences within these products, leveraging real-time information and user data (with appropriate privacy controls) to provide more personalized and effective assistance.
#
# **6. Openness and Accessibility (for Developers):**
#
# *   **API Access and Developer Tools:** Google provides APIs and tools to allow developers to integrate Gemini into their own applications. The availability of different model sizes (Ultra, Pro, Nano) caters to various needs.
#     *   **Advantage:** This empowers developers to build innovative solutions and leverage Gemini's capabilities for a wide range of use cases.
#
# **7. Focus on Responsible AI:**
#
# *   **Safety and Ethics:** Google emphasizes responsible AI development and deployment, with a focus on mitigating biases and ensuring safety in their models.
#     *   **Advantage:** While all major providers are working on this, Google's commitment to responsible AI can be a significant factor for organizations and users prioritizing ethical AI interactions.
#
# **Comparison Points to Consider with Other Providers:**
#
# *   **OpenAI (GPT series):** OpenAI's GPT models are renowned for their powerful text generation, conversational abilities, and broad knowledge base. Gemini aims to compete and differentiate with its native multimodality and advanced reasoning.
# *   **Meta AI (LLaMA series):** Meta's LLaMA models are often praised for their open-source nature and strong performance, enabling wider community research and development. Gemini's proprietary nature and deep integration with Google's infrastructure offer a different set of advantages.
# *   **Anthropic (Claude series):** Anthropic's Claude models are known for their focus on helpfulness, honesty, and harmlessness, with a strong emphasis on constitutional AI. Gemini competes by offering broad capabilities with a similar focus on responsible AI.
#
# **Important Caveats:**
#
# *   **"Other Providers" is Broad:** The LLM market has many players, each with their strengths. The advantages of Gemini will be compared against specific models from other providers.
# *   **Rapid Evolution:** The field is moving incredibly fast. What is an advantage today might be matched or surpassed by competitors tomorrow.
# *   **Task Specificity:** The "best" LLM often depends on the specific task. Gemini might excel in multimodal reasoning, while another LLM might be more fine-tuned for creative writing or code generation.
# *   **Benchmarks and Real-World Performance:** While benchmarks are useful, real-world performance can vary. It's essential to test and evaluate LLMs for your specific use cases.
#
# In summary, Gemini's key differentiators lie in its **native multimodality, advanced reasoning capabilities, and the potential for deep integration within the Google ecosystem**, making it a compelling option for a wide range of AI-powered applications."""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash-lite',
#   response_id='jW74afuHEMvJjuMP3rrS8Ak',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=12>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=1089,
#     prompt_token_count=13,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=13
#       ),
#     ],
#     total_token_count=1102
#   )
# )

# %%
# Print the response
print(response.text)
# Out:
# Gemini LLMs, as developed by Google AI, offer several potential advantages over LLMs from other providers. It's important to note that the LLM landscape is constantly evolving, and specific advantages can depend on the exact model version and the task at hand. However, here are some of the key strengths and potential advantages often attributed to Gemini:
#
# **1. Multimodality:**
#
# *   **Native Understanding of Multiple Data Types:** This is a flagship feature of Gemini. Unlike many other LLMs that might process different modalities (text, images, audio, video, code) separately or require significant pre-processing to integrate them, Gemini is designed to understand and reason across these modalities **natively and jointly**.
#     *   **Advantage:** This allows for richer interactions, more complex problem-solving, and the ability to draw insights from diverse information sources simultaneously. For example, you could ask Gemini to analyze a chart in an image and then explain its implications in text, or to describe a video and then generate code to recreate a similar effect.
#
# **2. Advanced Reasoning Capabilities:**
#
# *   **Complex Problem Solving:** Gemini has demonstrated strong performance on challenging reasoning benchmarks, including those that require logical deduction, common-sense reasoning, and understanding intricate relationships.
#     *   **Advantage:** This leads to more accurate and insightful responses to complex questions, better decision-making support, and the ability to tackle more sophisticated analytical tasks.
#
# **3. Performance and Efficiency:**
#
# *   **Optimized for Speed and Scalability:** Google has invested heavily in optimizing Gemini for efficient inference and scalability, leveraging their extensive infrastructure.
#     *   **Advantage:** This can translate to faster response times and the ability to handle a larger volume of requests, which is crucial for real-world applications and businesses.
#
# **4. State-of-the-Art Architecture and Training:**
#
# *   **Cutting-Edge Research:** Gemini benefits from Google's deep research in AI, including advancements in neural network architectures, training methodologies, and reinforcement learning.
#     *   **Advantage:** This foundation often results in models that are at the forefront of natural language understanding, generation, and reasoning capabilities.
#
# **5. Potential for Deep Integration with Google Ecosystem:**
#
# *   **Synergy with Google Products:** While not exclusively an advantage of the LLM itself, Gemini's origin within Google suggests potential for seamless integration with other Google services like Search, Workspace, Cloud, and Android.
#     *   **Advantage:** This could lead to more context-aware and helpful experiences within these products, leveraging real-time information and user data (with appropriate privacy controls) to provide more personalized and effective assistance.
#
# **6. Openness and Accessibility (for Developers):**
#
# *   **API Access and Developer Tools:** Google provides APIs and tools to allow developers to integrate Gemini into their own applications. The availability of different model sizes (Ultra, Pro, Nano) caters to various needs.
#     *   **Advantage:** This empowers developers to build innovative solutions and leverage Gemini's capabilities for a wide range of use cases.
#
# **7. Focus on Responsible AI:**
#
# *   **Safety and Ethics:** Google emphasizes responsible AI development and deployment, with a focus on mitigating biases and ensuring safety in their models.
#     *   **Advantage:** While all major providers are working on this, Google's commitment to responsible AI can be a significant factor for organizations and users prioritizing ethical AI interactions.
#
# **Comparison Points to Consider with Other Providers:**
#
# *   **OpenAI (GPT series):** OpenAI's GPT models are renowned for their powerful text generation, conversational abilities, and broad knowledge base. Gemini aims to compete and differentiate with its native multimodality and advanced reasoning.
# *   **Meta AI (LLaMA series):** Meta's LLaMA models are often praised for their open-source nature and strong performance, enabling wider community research and development. Gemini's proprietary nature and deep integration with Google's infrastructure offer a different set of advantages.
# *   **Anthropic (Claude series):** Anthropic's Claude models are known for their focus on helpfulness, honesty, and harmlessness, with a strong emphasis on constitutional AI. Gemini competes by offering broad capabilities with a similar focus on responsible AI.
#
# **Important Caveats:**
#
# *   **"Other Providers" is Broad:** The LLM market has many players, each with their strengths. The advantages of Gemini will be compared against specific models from other providers.
# *   **Rapid Evolution:** The field is moving incredibly fast. What is an advantage today might be matched or surpassed by competitors tomorrow.
# *   **Task Specificity:** The "best" LLM often depends on the specific task. Gemini might excel in multimodal reasoning, while another LLM might be more fine-tuned for creative writing or code generation.
# *   **Benchmarks and Real-World Performance:** While benchmarks are useful, real-world performance can vary. It's essential to test and evaluate LLMs for your specific use cases.
#
# In summary, Gemini's key differentiators lie in its **native multimodality, advanced reasoning capabilities, and the potential for deep integration within the Google ecosystem**, making it a compelling option for a wide range of AI-powered applications.
