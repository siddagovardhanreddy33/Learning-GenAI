# %%
print('Hello world')
# Out:
# Hello world

# %%
from google import genai

# %% [markdown]
# ### Not recommended practice

# %%
## clint - through api key , can access Genai LLM - available in google server

# %%
# not recomanded practice
# client = genai.Client(api_key='YOUR_API_KEY')  

# clint = genai.client() 
# clint

# %% [markdown]
# ### Recommended

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os

# %%
os.environ['GEMINI_API_KEY']=os.getenv('gemini')

# %%
from google import genai

# %%
client = genai.Client()
client

# %%
# Generate response using Gemini model

response = client.models.generate_content(
    model='gemini-2.5-flash-lite',  # Model name
    contents='what are the advantages of gemini llms over other providers'  # Prompt
)

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""Gemini LLMs, developed by Google AI, offer a compelling set of advantages over other large language model providers. These advantages stem from its architecture, training, and Google's broader ecosystem. Here's a breakdown of the key benefits:
#
# **1. Multimodality as a Core Design Principle:**
#
# *   **Native Multimodality:** Unlike many LLMs that are primarily text-based and then adapted for other modalities, Gemini was designed from the ground up to be multimodal. This means it can natively understand, operate across, and combine different types of information like text, code, audio, images, and video.
# *   **Deeper Understanding:** This native multimodality allows Gemini to build a more profound and interconnected understanding of information. It can reason across different modalities in a way that separate unimodal models often struggle with. For example, it can describe an image, then answer questions about it based on accompanying text, and even generate code that relates to its visual elements.
#
# **2. Advanced Reasoning and Problem-Solving Capabilities:**
#
# *   **Sophisticated Reasoning:** Gemini exhibits impressive reasoning abilities, particularly in complex scenarios. This includes understanding context, identifying relationships, drawing inferences, and solving logical puzzles.
# *   **Code Generation and Understanding:** Gemini's proficiency in code generation and understanding is a significant advantage. It can write, debug, and explain code in various programming languages, making it a powerful tool for developers.
# *   **Mathematical and Scientific Understanding:** Gemini has shown strong capabilities in understanding and processing mathematical and scientific concepts, which is crucial for more specialized applications.
#
# **3. Performance and Efficiency:**
#
# *   **Optimized Architecture:** Gemini's architecture is designed for efficiency and performance, allowing it to handle complex tasks with greater speed.
# *   **Scalability:** It's built to scale, enabling it to be deployed across various applications and handle large-scale workloads.
# *   **Different Versions for Different Needs:** Google has released different versions of Gemini (e.g., Ultra, Pro, Nano) tailored to specific use cases, from highly complex tasks to on-device applications. This provides flexibility and optimizes resource utilization.
#
# **4. Integration with Google's Ecosystem:**
#
# *   **Leveraging Google's Data and Infrastructure:** Gemini benefits from Google's vast and diverse datasets and its cutting-edge infrastructure. This allows for more robust training and development.
# *   **Seamless Integration with Google Products:** Gemini is being integrated into various Google products and services, such as Workspace (Docs, Sheets, Slides), Search, and Cloud AI. This offers users a familiar and powerful AI experience within their existing workflows.
# *   **Access to Google's Research:** Being a Google product, Gemini benefits from the continuous research and development within Google AI, ensuring it remains at the forefront of LLM technology.
#
# **5. Safety and Responsibility:**
#
# *   **Focus on Responsible AI:** Google has a strong emphasis on developing AI responsibly and ethically. Gemini incorporates safety guardrails and is designed to mitigate bias and harmful outputs, aiming for more trustworthy AI.
# *   **Continuous Improvement in Safety:** Efforts are ongoing to continuously improve Gemini's safety features and address emerging concerns.
#
# **6. Flexibility and Adaptability:**
#
# *   **Fine-tuning Capabilities:** Gemini models can be fine-tuned for specific tasks and domains, allowing businesses and developers to tailor the LLM to their unique needs.
# *   **Broad Application Range:** Its versatility makes it suitable for a wide array of applications, from creative writing and content generation to complex data analysis and scientific research.
#
# **In summary, the key advantages of Gemini LLMs over other providers often revolve around:**
#
# *   **Native multimodality and the resulting deeper understanding.**
# *   **Superior reasoning and problem-solving capabilities.**
# *   **Strong performance, efficiency, and scalability.**
# *   **Seamless integration with Google's vast ecosystem.**
# *   **A commitment to responsible AI development.**
#
# While other LLM providers also offer impressive capabilities, Gemini's holistic approach to multimodality, its integration with Google's strengths, and its focus on advanced reasoning position it as a leading contender in the LLM landscape."""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash-lite',
#   response_id='6HP4ab7BBe7V4-EPrdzq-Qg',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=12>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=864,
#     prompt_token_count=13,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=13
#       ),
#     ],
#     total_token_count=877
#   )
# )

# %%
# Print the response
print(response.text)
# Out:
# Gemini LLMs, developed by Google AI, offer a compelling set of advantages over other large language model providers. These advantages stem from its architecture, training, and Google's broader ecosystem. Here's a breakdown of the key benefits:
#
# **1. Multimodality as a Core Design Principle:**
#
# *   **Native Multimodality:** Unlike many LLMs that are primarily text-based and then adapted for other modalities, Gemini was designed from the ground up to be multimodal. This means it can natively understand, operate across, and combine different types of information like text, code, audio, images, and video.
# *   **Deeper Understanding:** This native multimodality allows Gemini to build a more profound and interconnected understanding of information. It can reason across different modalities in a way that separate unimodal models often struggle with. For example, it can describe an image, then answer questions about it based on accompanying text, and even generate code that relates to its visual elements.
#
# **2. Advanced Reasoning and Problem-Solving Capabilities:**
#
# *   **Sophisticated Reasoning:** Gemini exhibits impressive reasoning abilities, particularly in complex scenarios. This includes understanding context, identifying relationships, drawing inferences, and solving logical puzzles.
# *   **Code Generation and Understanding:** Gemini's proficiency in code generation and understanding is a significant advantage. It can write, debug, and explain code in various programming languages, making it a powerful tool for developers.
# *   **Mathematical and Scientific Understanding:** Gemini has shown strong capabilities in understanding and processing mathematical and scientific concepts, which is crucial for more specialized applications.
#
# **3. Performance and Efficiency:**
#
# *   **Optimized Architecture:** Gemini's architecture is designed for efficiency and performance, allowing it to handle complex tasks with greater speed.
# *   **Scalability:** It's built to scale, enabling it to be deployed across various applications and handle large-scale workloads.
# *   **Different Versions for Different Needs:** Google has released different versions of Gemini (e.g., Ultra, Pro, Nano) tailored to specific use cases, from highly complex tasks to on-device applications. This provides flexibility and optimizes resource utilization.
#
# **4. Integration with Google's Ecosystem:**
#
# *   **Leveraging Google's Data and Infrastructure:** Gemini benefits from Google's vast and diverse datasets and its cutting-edge infrastructure. This allows for more robust training and development.
# *   **Seamless Integration with Google Products:** Gemini is being integrated into various Google products and services, such as Workspace (Docs, Sheets, Slides), Search, and Cloud AI. This offers users a familiar and powerful AI experience within their existing workflows.
# *   **Access to Google's Research:** Being a Google product, Gemini benefits from the continuous research and development within Google AI, ensuring it remains at the forefront of LLM technology.
#
# **5. Safety and Responsibility:**
#
# *   **Focus on Responsible AI:** Google has a strong emphasis on developing AI responsibly and ethically. Gemini incorporates safety guardrails and is designed to mitigate bias and harmful outputs, aiming for more trustworthy AI.
# *   **Continuous Improvement in Safety:** Efforts are ongoing to continuously improve Gemini's safety features and address emerging concerns.
#
# **6. Flexibility and Adaptability:**
#
# *   **Fine-tuning Capabilities:** Gemini models can be fine-tuned for specific tasks and domains, allowing businesses and developers to tailor the LLM to their unique needs.
# *   **Broad Application Range:** Its versatility makes it suitable for a wide array of applications, from creative writing and content generation to complex data analysis and scientific research.
#
# **In summary, the key advantages of Gemini LLMs over other providers often revolve around:**
#
# *   **Native multimodality and the resulting deeper understanding.**
# *   **Superior reasoning and problem-solving capabilities.**
# *   **Strong performance, efficiency, and scalability.**
# *   **Seamless integration with Google's vast ecosystem.**
# *   **A commitment to responsible AI development.**
#
# While other LLM providers also offer impressive capabilities, Gemini's holistic approach to multimodality, its integration with Google's strengths, and its focus on advanced reasoning position it as a leading contender in the LLM landscape.
